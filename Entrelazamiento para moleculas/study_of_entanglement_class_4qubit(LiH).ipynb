# %% [markdown]
# # General Explanation:
#
# In the present jupyer notebook, we will desglose the work for characterizing how entanglement is relevant in the anastz embedding and in the finding of the ground state for quantum chemistry problems.

# %% [markdown]
# Preeliminaries:
#
# In Variational Quantum Algorithms (VQA), It is usual to define a cost function, given a Quantum State $\rho = \ket{\psi}\bra{\psi}$ and an Observable $\mathcal{O}$ such that:
#
# $$
# C(\rho, \mathcal{O}) = \text{Tr}(\rho \mathcal{O})
# = \text{tr}(\ket{\psi}\bra{\psi} O  ) = \bra{\psi} \mathcal{O} \ket{\psi}\
# $$
# and then minimize it or optimize it in order to tackle down optimization Problems.
#
# An issue with this method, is that often exploring the whole landscape of states it's an exponential task. (the so-called curse of dimensionality)
#
# Several methods have been developed utilizing the stabilizer formalism, correct walk at the Hilbert Space, and so on.
#
# In this case, we are going to explore how different classes of entanglement can contribute to find the ground state of a molecular Hamiltonian.
#
# For this case, we now that a Molecular Hamiltonian can be expresed by the electronic structure Hamiltonian, $\mathcal{H}_{\text{ES}}$:
#
# $$
# \mathcal{H}_{\text{ES}} =  T_{N} + T_{e} + V_{ee}^{\text{Coulomb}} + V_{en}^{\text{Coulomb}} + V_{nn}^{\text{Coulomb}}
# $$
#
# Where $T_{N}, T_{e} $ are the kinetic energy of the Nuclei and electrons, respectively, while $V_{ee}^{\text{Coulomb}}, V_{en}^{\text{Coulomb}}, V_{nn}^{\text{Coulomb}}$ are the coulomb interactions between electron-electron, electron-nuclei and nuclei-nuclei respectively.
#
# In this case, by utilizing the B-O approx, we are going only to center on the 2nd, 3rd and 4th term. (which is a valid approximation because we want to focuse on the low-energy regime)
#
# In order to avoid the problem of barren plateau and correct ansatz preparation, we are going to characterize how well does different states of different classes computes the GS for 4-qubit problems.
#
# The idea is to reach all the Hilbert Space in these sub division of states, and the utilizing later to tackle down more efficiently these problems.

# %% [markdown]
# # Beggining:
#
# first, we are going to install the necesary packages:

# %%
# %pip install qutip
# %pip install pyscf
# %pip install qiskit_nature
# %pip install pylatexenc
# Out:
# Requirement already satisfied: qutip in /home/hd/workspace/.venv/lib/python3.11/site-packages (5.1.1)
# Requirement already satisfied: numpy>=1.22 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qutip) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qutip) (1.14.1)
# Requirement already satisfied: packaging in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qutip) (24.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyscf in /home/hd/workspace/.venv/lib/python3.11/site-packages (2.8.0)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from pyscf) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from pyscf) (1.14.1)
# Requirement already satisfied: h5py>=2.7 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from pyscf) (3.12.1)
# Requirement already satisfied: setuptools in /home/hd/workspace/.venv/lib/python3.11/site-packages (from pyscf) (65.5.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit_nature in /home/hd/workspace/.venv/lib/python3.11/site-packages (0.7.2)
# Requirement already satisfied: qiskit>=0.44 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (1.3.2)
# Requirement already satisfied: qiskit-algorithms>=0.2.1 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (0.3.1)
# Requirement already satisfied: scipy>=1.4 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (1.14.1)
# Requirement already satisfied: numpy>=1.17 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (1.26.4)
# Requirement already satisfied: psutil>=5 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (6.0.0)
# Requirement already satisfied: setuptools>=40.1.0 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (65.5.0)
# Requirement already satisfied: typing-extensions in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (4.12.2)
# Requirement already satisfied: h5py in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (3.12.1)
# Requirement already satisfied: rustworkx>=0.12 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit_nature) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit>=0.44->qiskit_nature) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit>=0.44->qiskit_nature) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit>=0.44->qiskit_nature) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit>=0.44->qiskit_nature) (5.4.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from qiskit>=0.44->qiskit_nature) (0.13.0)
# Requirement already satisfied: six>=1.5 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit>=0.44->qiskit_nature) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit>=0.44->qiskit_nature) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hd/workspace/.venv/lib/python3.11/site-packages (from sympy>=1.3->qiskit>=0.44->qiskit_nature) (1.3.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylatexenc in /home/hd/workspace/.venv/lib/python3.11/site-packages (2.10)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Operator creation:
#
# In this part, we are going to construc the Unitary operators that are going to be layered in the final class.

# %%
#We import the necesary libraries:
import qutip as qt
from qutip import Bloch, QobjEvo, basis, sesolve, sigmay, sigmaz
import numpy as np
import math
import cmath
import matplotlib.pyplot as plt
from scipy.constants import h, e

# %%
def unitary(theta: float, phi: float, lamb) -> np.ndarray:
    """
    The typical unitary matrix of a single qubit gate,
    parametrized as usual with only three rotational angle parameter.
    """
    c = np.cos(theta / 2)
    s = np.sin(theta / 2)
    e_phi = np.exp(1j * phi)
    e_lamb = np.exp(1j * lamb)

    return np.array([[c,                - e_lamb * s],
                     [e_phi * s,    e_lamb * e_phi * c  ]])



def U_qubit(N : int, k : int, params : np.array ):

    """
    N: number of total qubits
    k: label of the target qubit to apply the local unitary U
    params: list or array where it contains the parameters that characterize the unitary
    """

    # we define the matrix
    U = unitary(*params)

    # Converts from numpy array to Qobj of Qutip
    U_qobj = qt.Qobj(U)

    # We construct the tensorized operator in qutip
    L = [qt.qeye(2)] * N  # Lista con Identidades en todos los sitios
    L[k] = U_qobj  # Sustituye en el qubit k
    return qt.tensor(L)

# %%
# Num of qubits
N = 4

# Vector de parámetros (12 elementos en total: 3 por cada qubit)

#question: why these values?
#can this affect the convergence time?
params_vec = [np.pi/4, np.pi/3, np.pi/6,  # Qubit 0
              np.pi/2, np.pi/4, np.pi/8,  # Qubit 1
              np.pi/3, np.pi/6, np.pi/2,  # Qubit 2
              np.pi/8, np.pi/3, np.pi/4]  # Qubit 3

params_vecV2 = np.random.uniform(0, 2*np.pi, 12)

# Now we generate the unitary operators for each qubit

dict_op = {f'U_{i}': U_qubit(N, i, params_vec[3*i: 3*(i+1)]) for i in range(N)}


# Comprobamos los operadores generados
#print(dict_op['U_1'])
#...

# %% [markdown]
# In this part, we are going to construct The operator $\mathcal{H}_{\text{ES}}$. In order to do this we are going to utilize the PySCF package together with Qiskit Nature package:
#
# With this form, we can express the hamiltonian as a QuTIP object.

# %%
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.operators import FermionicOp
from qiskit_nature.second_q.transformers import FreezeCoreTransformer, ActiveSpaceTransformer




def H2_Hamiltonian_Operator(r_i):
    """
    This function returns the Hamiltonian operator of the H2
    molecule at a given distance r_i.

    args:
        r_i: distance between the two hydrogen atoms
    """

    driver = PySCFDriver(
        atom= f'H .0 .0 .0; H .0 .0 {r_i}',
        unit = DistanceUnit.ANGSTROM,
        basis= 'sto-3g',
    )

    problem = driver.run()
    second_q_ham = problem.hamiltonian.second_q_op()


    num_spin_orbitals = problem.num_spatial_orbitals
    identity_op = FermionicOp.one()

    # Escalar el operador identidad por la energía nuclear
    nuclear_energy_op = problem.nuclear_repulsion_energy * identity_op
    hamiltonian_without_nuclear = second_q_ham + nuclear_energy_op

    mapper = JordanWignerMapper()

    pauli_hamiltonian_op = mapper.map(hamiltonian_without_nuclear)
    matrix_representation = pauli_hamiltonian_op.to_matrix()
    qt_hamiltonian_op = qt.Qobj(matrix_representation, dims=[[2,2,2,2], [2,2,2,2]])

    return qt_hamiltonian_op



def LiH_Hamiltonian_Operator(r_i):
    """
    This function returns the Hamiltonian operator of the H2
    molecule at a given distance r_i.

    args:
        r_i: distance between the two hydrogen atoms
    """

    driver = PySCFDriver(atom=f"Li 0 0 0; H 0 0 {r_i}", basis="sto-3g")
    
    full_problem = driver.run()

    act_space_tf = ActiveSpaceTransformer(num_electrons= 2, num_spatial_orbitals= 2)

    problem = act_space_tf.transform(full_problem)
    hamiltonian = problem.hamiltonian.second_q_op()
    num_spin_orbitals = problem.num_spatial_orbitals
    identity_op = FermionicOp.one()

# Escalar el operador identidad por la energía nuclear
    nuclear_energy_op = problem.nuclear_repulsion_energy * identity_op
    AST_energy_op = problem.hamiltonian.constants['ActiveSpaceTransformer']*identity_op
    hamiltonian_without_nuclear = hamiltonian + nuclear_energy_op + AST_energy_op

    mapper = JordanWignerMapper()

    pauli_hamiltonian_op = mapper.map(hamiltonian_without_nuclear)
    matrix_representation = pauli_hamiltonian_op.to_matrix()
    qt_hamiltonian_op = qt.Qobj(matrix_representation, dims=[[2,2,2,2], [2,2,2,2]])

    return qt_hamiltonian_op

# %%
# me base de esto para escribir lo de abajo...

#N = 4
#s0 = qt.basis(2, 0)
#s1 = qt.basis(2, 1)

#ESTADOS DE CADA CLASE DE ENTRELAZAMIENTO
#psi_C9 = 1/2*(qt.tensor(s0,s0,s0,s0)+qt.tensor(s0,s1,s0,s1)+qt.tensor(s1,s0,s1,s0) + qt.tensor(s1,s1,s1,s1) )
#psi_C3 = 1/np.sqrt(2)*(qt.tensor(s0,s0,s0,s0)+ qt.tensor(s1,s0,s1,s0))
#psi_C1 = qt.tensor(s0,s0,s0,s0)
#psi_C11 = 1/np.sqrt(3)*(qt.tensor(s0,s0,s1,s0)+qt.tensor(s0,s1,s0,s0)+qt.tensor(s1,s0,s0,s0))
#psi_C15 = 1/np.sqrt(2)*(qt.tensor(s0,s0,s0,s0)+ qt.tensor(s1,s1,s1,s0))
#psi_C19 = 1/2*(qt.tensor(s1,s0,s0,s0)+qt.tensor(s0,s1,s0,s0)+qt.tensor(s0,s0,s1,s0)+ qt.tensor(s0,s0,s0,s1))
#psi_C26 = 1/np.sqrt(2)*(qt.tensor(s0,s0,s0,s0)+qt.tensor(s1,s1,s1,s1))
#psi_C48 = 1/np.sqrt(8)*(qt.tensor(s0,s0,s0,s0)+qt.tensor(s0,s0,s1,s1)+qt.tensor(s0,s1,s0,s1)+qt.tensor(s0,s1,s1,s0)+qt.tensor(s1,s0,s0,s0)-qt.tensor(s1,s0,s1,s1)+qt.tensor(s1,s1,s0,s1)-qt.tensor(s1,s1,s1,s0))

# %% [markdown]
# Aqui haré lo siguiente:
#
# 1) Creare una funcion `initialize_state(state_vector : np.array):` para que inicialize el objeto de qutip teniendole que darle solo la repr vectorial como un numpy array para que sea mas facil de generar los estados de manera arbitraria. De esta manera, podemos ver que los estados que utilizaremos serán:
# $$
# \ket{C_1} = \ket{0000} \\ \\
#
# \ket{C_3} = \frac{1}{\sqrt{2}} \big ( \ket{0000} + \ket{1010}  \big) \\ \\
#
# \ket{C_9} = \frac{1}{2} \big ( \ket{0000} + \ket{0101} + \ket{1010} + \ket{1111} \big)  \\ \\
#
# \ket{C_{11}} = \frac{1}{\sqrt{3}} \big (  \ket{0010} + \ket{0100} + \ket{1000}     \big ) = \ket{W} \otimes \ket{0} \\ \\
#
# \ket{C_{15}} = \frac{1}{\sqrt{2}} \big ( \ket{0000} + \ket{1110}  \big)                   = \ket{GHZ} \otimes \ket{0} \\ \\
#
# \ket{C_{19}} = \frac{1}{2} \big ( \ket{1000} + \ket{0100} + \ket{0010} + \ket{0001}\big) = \text{CNOT}_{q_2 \to q_3} \ket{W} ??? \\ \\
#
# \ket{C_{26}} = \frac{1}{\sqrt{2}} \big ( \ket{0000} + \ket{1111}  \big) = \ket{GHZ}_4 \\ \\
#
# \ket{C_{48}} = \frac{1}{\sqrt{8}} \big( \ket{0000} + \ket{0011} + \ket{0101} + \ket{0110} + \ket{1000} - \ket{1011} + \ket{1101} - \ket{1110} \\ \\
#   \big ) \\ \\
#
# \text{We need to fill up the 27 states... cositas se vienen!}
# $$
#
# where we are going to utilize the notation of: $\ket{q0, q1, q2, q3}$
#
# 2) luego, crearé una función que aplique el ansatz a utilizar `apply_ansatz(qt_state_vector : qt.tensor, params_vector : np.array):` , que será explorar de manera constante el espacio de Hilbert, en función de los posibles estados que pertenezcan a una misma clase. Para poder lograr esto es utilizar la definición matemática de similitud bajo transformaciones unitarias locales: $\ket{\psi'} = U \ket{\psi}$ para nuestro caso, esto se logra definiendo $U = U(\theta_0, \phi_0, \lambda_0) \otimes U(\theta_1, \phi_1, \lambda_1) \otimes U(\theta_2, \phi_2, \lambda_2) \otimes U(\theta_3, \phi_3, \lambda_3)$ y optimizaremos de manera manera constante con respecto a cada una de las clases, y que crece de manera lineal con el numero de qubits: ( ` Num_of_param = 3*N ` ).
#
# Al final, lo que hacemos es algo así:
#
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Inicializar el Hamiltoniano y con el estado final $\ket{\psi}(\vec{\theta})$ calcular el valor de expectación de este operador que ya sabemos como hacerlo. Aqui generaremos la famosa función de costo: $\langle \mathcal{H}_{\text{ES}} \rangle (\vec{\theta})$ esto lo haremos con el codigo que ya estaba del Diego con el método `qt.expect(H, state)`
#
# 4) ver que tanto se parecen estos resultados al resultado de referencia:
#
# Aqui hago una hipotesis/pregunta: ¿Habrán clases que lo hagan mejor en unos regimenes (por ej, regimen de equilibrio lo harán mejor los estados separables, mientras que en regimenes disosiativos serán mejor estados que si presenten cierto grado de entrelazamiento?)?
#
# Es posible que una interpretación del entrelazamiento, se manifieste cuando es necesario utilizar el multiconfiguration formalism/una forma de ver que tanto ven los unos de los otros al mismo tiempo???? interpretacion de quantum mechanics lolaso..

# %%
def initialize_state(state_vector : np.array) -> qt.tensor:

    # We define the basis of one qubit
    s_0 = qt.basis(2, 0)
    s_1 = qt.basis(2, 1)
    basis_states = [s_0, s_1]

    # We construct the quantum state as intended
    quantum_state = sum(
        state_vector[i] * qt.tensor(
            basis_states[(i >> 3) & 1],  # Qubit 1
            basis_states[(i >> 2) & 1],  # Qubit 2
            basis_states[(i >> 1) & 1],  # Qubit 3
            basis_states[(i >> 0) & 1]   # Qubit 4
        )
        for i in range(16)
    )

    # We normalize the state:
    quantum_state = quantum_state.unit()
    return quantum_state


def apply_ansatz(qt_state_vector : qt.tensor, params_vector : np.array) -> qt.tensor:


    U_i = [U_qubit(N, i, params_vector[3*i: 3*(i+1)]) for i in range(4)]

    layered_state = U_i[3] * U_i[2] * U_i[1] * U_i[0] * qt_state_vector

    return layered_state

    #TO DO: try to implement this in a more efficient and general way...
    """
    # Create a dictionary of unitary operators for each qubit using U_qubit
    dict_op = {f'U_{i}': U_qubit(N, i, params_vector[3*i: 3*(i+1)]) for i in range(N)}

    # Initialize the layered_state as the identity (no operation)
    layered_state = qt.qeye(2**N)  # Identity matrix of dimension 2^N

    # Apply each unitary operator to the state vector
    for i in range(N):
        # Apply the tensor product of all U_i up to i-th qubit


        layered_state = qt.tensor(*[dict_op[f'U_{j}'] if j == i else qt.qeye(2) for j in range(N)]) * qt_state_vector

    return layered_state
    """


def cost_func(params_vec : np.array, *args) -> float:
    """
    Function to optimize: we will be optimizing the set of parameters of the Unitary.

    Args:
        params_vec: array of parameters for the Unitary.
        Hamiltonian: Hamiltonian operator of the system.
        state_vector: initial state of the system.
        N: number of qubits in the system.

    Returns:
        float: Expectation value of the Hamiltonian for the given state and parameters.
    """
    Hamiltonian = args[0]
    state_vector = args[1]

    initial_class_state = initialize_state(state_vector)
    ansatz = apply_ansatz(initial_class_state, params_vec)

    return qt.expect(Hamiltonian, ansatz)

# %%
#dataset_clases


#psi_class = give here the np.array(statevector...):
#For simplisity, I'm going to put only C1, C3, C9, C26 and C48
#find a clever way to do this, it does not matter a lot bcs is initialized once but it works by now...
# At the moment I'm utilizing the module qiskit.quantum_info to initialize it with the usual nomenclature of
# |0000>, |1010>, etc...

from qiskit.quantum_info import Statevector as SV

dataset_classes = {
    'C1' : SV.from_label('0000').data,
    'C3' : SV.from_label('0000').data + SV.from_label('1010').data,
    'C9' : SV.from_label('0000').data + SV.from_label('0101').data + SV.from_label('1010').data + SV.from_label('1111').data,
    'C11' : SV.from_label('0010') + SV.from_label('0100') + SV.from_label('1000'),
    'C15' : SV.from_label('0000').data + SV.from_label('1110').data,
    'C19' : SV.from_label('1000').data + SV.from_label('0100').data + SV.from_label('0010').data + SV.from_label('0001').data,
    'C26' : SV.from_label('0000').data + SV.from_label('1111').data,
    'C48' : SV.from_label('0000').data + SV.from_label('0011').data + SV.from_label('0101').data + SV.from_label('0110').data + SV.from_label('1000').data - SV.from_label('1011').data + SV.from_label('1101').data - SV.from_label('1110').data

}

final_dataset = {key : state / np.linalg.norm(state) for key, state in dataset_classes.items()}
availiable_classes = [key for key in final_dataset.keys()]

# Here the dataset is in the form of { Ci : |Ci> }
# Where Ci is the name of the class (str) and |Ci> the statevector of the class (np.array)

print(availiable_classes)
# Out:
# ['C1', 'C3', 'C9', 'C11', 'C15', 'C19', 'C26', 'C48']

# %%
import numpy as np
from scipy.optimize import minimize


distances = np.arange(0.5, 2.5, 0.05)

# Definir los límites de los parámetros de manera más eficiente
bounds = [(0, np.pi) if i % 3 == 0 else (0, 2 * np.pi) for i in range(12)]

try_initial_psi_class = dataset_classes['C1']

energies = np.zeros(shape= (len(availiable_classes), len(distances) ))
energies_real = np.zeros(len(distances))
for j, rj in enumerate(distances):
      qt_H2_hamiltonian = LiH_Hamiltonian_Operator(rj)
      energies_real[j] = qt_H2_hamiltonian.eigenenergies()[0]

      for i, Ci in enumerate(availiable_classes):
        try_initial_psi_class = dataset_classes[Ci]

        # We first initialize our Hamiltonian & choose the quantum state
        # perteneciente a la clase C_i
    

        # Inicialización de los parámetros aleatorios dentro de los límites
        init_params_vec = np.array([np.random.uniform(low, high) for low, high in bounds])

        # Argumentos de la función de costo

        args1 = (qt_H2_hamiltonian, try_initial_psi_class)  # Estado de la clase de entrelazamiento, Hamiltoniano de la molécula

        # Minimización usando COBYLA
        VQE = minimize(cost_func, init_params_vec, args=args1,
                    method='COBYLA', bounds=bounds,
                    options={'maxiter': 1500, 'disp': True})

        energies[i][j] = VQE.fun
# Out:
#    Normal return from subroutine COBYLA
#
#    NFVALS =  225   F =-7.028410E+00    MAXCV = 1.099437E-17
#    X = 1.926896E-17   1.743266E+00   7.432956E-01   3.141593E+00   5.624208E+00
#        2.707592E+00  -1.099437E-17   6.013506E+00   4.797175E-01   3.141593E+00
#        1.233254E+00   5.886803E-01
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  450   F =-7.006331E+00    MAXCV = 0.000000E+00
#    X = 1.009482E+00   3.712976E+00   6.096797E+00   3.141185E+00   4.350705E+00
#        1.212503E+00   2.132094E+00   2.073369E+00   3.327881E+00   3.141173E+00
#        5.959873E+00   3.178548E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  149   F =-6.994489E+00    MAXCV =-0.000000E+00
#    X = 1.079967E-20   1.996604E+00   1.182273E+00   3.141593E+00   2.348695E+00
#        2.774553E+00   3.141593E+00   2.043254E+00   1.680386E+00   4.884328E-05
#        3.431764E+00   2.751279E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  562   F =-7.001151E+00    MAXCV = 0.000000E+00
#    X = 3.728748E-04   3.436081E+00   4.949331E+00   3.379312E-04   6.136367E+00
#        3.208373E+00   4.195465E-04   4.258699E+00   1.067230E+00   3.141593E+00
#        1.778840E+00   4.942315E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  903   F =-7.000410E+00    MAXCV = 3.075028E-20
#    X =-3.075028E-20   5.927698E+00   2.030494E-02  -3.037041E-20   3.363460E+00
#        1.291097E+00   3.141533E+00   3.756391E+00   6.282444E+00   3.141548E+00
#        2.519370E+00   4.876236E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  671   F =-6.962942E+00    MAXCV = 0.000000E+00
#    X = 1.928430E+00   5.267415E+00   2.243855E+00   3.140551E+00   3.024655E+00
#        6.283150E+00   1.928451E+00   3.736106E+00   5.385610E+00   3.140325E+00
#        1.627290E+00   3.276547E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  162   F =-6.994489E+00    MAXCV = 4.440892E-16
#    X = 3.141593E+00   3.210196E+00   1.595693E-05   3.141593E+00  -9.339900E-20
#        6.577450E-02  -9.347692E-20   5.494142E+00   4.878385E+00  -9.348403E-20
#        2.161657E+00   5.570637E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  198   F =-6.994489E+00    MAXCV = 0.000000E+00
#    X = 1.570861E+00   2.299299E+00   4.404571E-20   1.570826E+00   1.581186E+00
#        3.141590E+00   3.218725E-20   4.961363E+00   2.768936E+00   1.570825E+00
#        7.290156E-01   6.283185E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  168   F =-7.177139E+00    MAXCV = 4.440892E-16
#    X =-1.292470E-26   5.767025E+00   2.524032E+00   3.141593E+00   3.147995E+00
#        5.109739E+00  -3.690328E-25   4.479044E+00   4.194575E+00   3.141593E+00
#        3.392415E+00   1.887670E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =
+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  151   F =-7.710988E+00    MAXCV = 4.440892E-16
#    X = 3.141593E+00   5.385116E+00   6.283185E+00   3.141593E+00   3.516040E+00
#        1.422840E+00  -4.091403E-17   5.676025E+00   2.274043E+00   3.141593E+00
#        3.216315E+00   2.797163E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  417   F =-7.710545E+00    MAXCV = 0.000000E+00
#    X = 2.874433E+00   3.540361E+00   2.156887E+00   1.916517E+00   1.923158E+00
#        5.938746E+00   2.671845E-01   5.767875E+00   9.860940E-01   1.225035E+00
#        1.010645E+00   3.485925E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  236   F =-7.722592E+00    MAXCV = 1.374138E-19
#    X = 5.585566E-20   3.716153E+00   3.360216E+00  -8.185581E-20   5.911427E+00
#        2.274600E+00  -1.374138E-19   6.262452E+00   5.884661E+00   3.141504E+00
#        3.793709E+00   3.084283E-01
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  133   F =-7.710766E+00    MAXCV =-0.000000E+00
#    X = 3.141593E+00   1.599108E+00   2.081982E+00   3.141593E+00   2.269170E-01
#        1.521178E+00   2.513584E-21   7.763109E-02   2.924866E+00   3.141557E+00
#        2.395578E+00   5.838193E-03
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  380   F =-7.676041E+00    MAXCV = 0.000000E+00
#    X = 1.508908E+00   4.187450E+00   3.300117E+00   3.141380E+00   4.028678E+00
#        6.282893E+00   1.508943E+00   2.446111E-01   1.584792E-01   3.141292E+00
#        5.618095E+00   2.390643E+00
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  109   F =-7.710545E+00    MAXCV = 5.903821E-22
#    X = 3.141585E+00   6.153709E+00   6.084425E+00   3.141593E+00   5.345991E+00
#        2.364500E+00   5.551115E-21   2.920079E+00   6.041975E+00  -5.903821E-22
#        5.808256E+00   3.795515E-01
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  219   F =-7.710545E+00    MAXCV = 1.863472E-20
#    X = 1.570834E+00   6.147948E+00  -1.863472E-20   1.570799E+00   5.167468E+00
#        6.283185E+00  -6.776264E-21   2.479444E+00   4.880813E+00   1.570770E+00
#        3.238144E+00   3.141594E+00

# %%
# Create a dictionary where the key is 'Ci' and the value is a tuple (distances, energies)
data_dict = {}

for i, Ci in enumerate(availiable_classes):
    energies_for_class = energies[i]  # Energies for this class (for all distances)
    data_dict[Ci] = (distances, energies_for_class)

# Save the dictionary
np.savez("energies_distances_LiH.npz", **data_dict)
np.savez("reference_LiH_energy.npz", energies_real)

# %%
# Load the saved dictionary
loaded_data = np.load("energies_distances_LiH.npz", allow_pickle=True)
distances = np.arange(0.5, 2.5, 0.05)

# Access data for a specific class, e.g., 'C1'
C1_distances, C1_energies = loaded_data['C1']

print(f"C1 distances: {C1_distances}")
print(f"C1 energies: {C1_energies}")


# I did this because as we find more classes, we only compute the VQE for that class in specific
# Out:
# C1 distances: [0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15
#  1.2  1.25 1.3  1.35 1.4  1.45 1.5  1.55 1.6  1.65 1.7  1.75 1.8  1.85
#  1.9  1.95 2.   2.05 2.1  2.15 2.2  2.25 2.3  2.35 2.4  2.45]
# C1 energies: [-7.02841009 -7.17713947 -7.29954105 -7.40117989 -7.48594487 -7.55672166
#  -7.61577016 -7.6649338  -7.70575334 -7.73952974 -7.76736214 -7.7901753
#  -7.80874318 -7.82371099 -7.83561583 -7.84490532 -7.85195386 -7.85707622
#  -7.86053866 -7.86256779 -7.86335762 -7.86307516 -7.86186477 -7.8598517
#  -7.85714496 -7.8538396  -7.8500187  -7.84575494 -7.84111204 -7.83614589
#  -7.83090558 -7.82543434 -7.81977026 -7.81394699 -7.80799437 -7.80193896
#  -7.79580448 -7.78961228 -7.78338163 -7.71105324]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Create a color map (Viridis) with as many colors as the number of classes
cmap = cm.get_cmap('viridis', len(availiable_classes))


plt.figure(figsize=(10, 6), dpi=300)  # High-quality figure

# Loop over each class and assign colors from the Viridis colormap
for i, Ci in enumerate(availiable_classes):
    color = cmap(i / len(availiable_classes))  # Normalize index to [0,1] for colormap

    Ci_distances, Ci_energies = loaded_data[Ci]

    plt.plot(Ci_distances, Ci_energies, 'o-', label=f'Class {Ci}', color=color, linewidth=2, markersize=6)



plt.plot(distances, energies_real, 'o-', label='Exact Energy', color='black', linewidth=2, markersize=6)



# Labels, title, and styles
plt.xlabel('Intermolecular Distance (Å)', fontsize=14)
plt.ylabel('Energy (Hartree)', fontsize=14)
plt.title('Energy vs Distance for Different Classes (LiH)', fontsize=16, fontweight='bold')

#Esto es para hacer zoom automatico
#plt.xlim((0.3, 1))


# Aesthetic improvements
plt.legend(title='Classes', fontsize=12, title_fontsize=13, loc='best', frameon=True)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_11382/2379465063.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis', len(availiable_classes))

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Create a color map (Viridis) with as many colors as the number of classes
cmap = cm.get_cmap('viridis', len(availiable_classes))

plt.figure(figsize=(10, 6), dpi=300)  # High-quality figure

# Loop over each class and assign colors from the Viridis colormap
for i, Ci in enumerate(availiable_classes):
    color = cmap(i / len(availiable_classes))  # Normalize index to [0,1] for colormap

    Ci_distances, Ci_energies = loaded_data[Ci]

    plt.plot(Ci_distances, Ci_energies, 'o-', label=f'Class {Ci}', color=color, linewidth=2, markersize=6)




plt.plot(distances, energies_real, 'o-', label='Exact Energy', color='black', linewidth=2, markersize=6)


# Labels, title, and styles
plt.xlabel('Intermolecular Distance (Å)', fontsize=14)
plt.ylabel('Energy (Hartree)', fontsize=14)
plt.title('Energy vs Distance for Different Classes', fontsize=16, fontweight='bold')

#Esto es para hacer zoom automatico
plt.xlim((1.4, 1.8))
plt.ylim((-8, -6.8))

# Aesthetic improvements
plt.legend(title='Classes', fontsize=12, title_fontsize=13, loc='best', frameon=True)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_11382/3007879239.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis', len(availiable_classes))

# %%
loaded_data['C1'][1]
# Out:
# array([-7.02841009, -7.17713947, -7.29954105, -7.40117989, -7.48594487,
#        -7.55672166, -7.61577016, -7.6649338 , -7.70575334, -7.73952974,
#        -7.76736214, -7.7901753 , -7.80874318, -7.82371099, -7.83561583,
#        -7.84490532, -7.85195386, -7.85707622, -7.86053866, -7.86256779,
#        -7.86335762, -7.86307516, -7.86186477, -7.8598517 , -7.85714496,
#        -7.8538396 , -7.8500187 , -7.84575494, -7.84111204, -7.83614589,
#        -7.83090558, -7.82543434, -7.81977026, -7.81394699, -7.80799437,
#        -7.80193896, -7.79580448, -7.78961228, -7.78338163, -7.77713007])

# %%
energies_real
# Out:
# array([-7.02905229, -7.17746156, -7.29977264, -7.40137274, -7.48611523,
#        -7.55687721, -7.61591576, -7.66507301, -7.70588892, -7.73966389,
#        -7.7674967 , -7.79031186, -7.80888318, -7.8238558 , -7.83576681,
#        -7.84506387, -7.85212149, -7.85725456, -7.86072951, -7.86277316,
#        -7.86357982, -7.8633168 , -7.86212883, -7.86014164, -7.85746475,
#        -7.85419386, -7.85041279, -7.84619513, -7.84160567, -7.8367016 ,
#        -7.83153363, -7.82614687, -7.8205818 , -7.81487498, -7.80905984,
#        -7.80316739, -7.79722684, -7.79126635, -7.78531362, -7.7793966 ])

# %% [markdown]
# # 2nd session of Coding:
#
# 1) Now we are going to implement the corrections of integrating the nuclear repulsion of the atoms.
# 2) See to which class corresponds the VQE ansatz ground state. Compare it with the knowing info.
#
#
# ## 2.1) Characterizing the class of the UCCSD Ansatz:
#
# Here, we are going to implement the UCCSD Ansatz, which is considered to be the golden standard[poner ref] at
# Quantum Chemistry, and compute it's polynomial invariants $h_1, h_2, h_3, h_{4i}$ that fully characterize
# to which class an state corresponds.
#
# Here we are going to implement the code provided by Vicente to fully characterize the class of a state, given its `state_vector` and a little bit of past code to initialize the UCCSD chemical ansatz:

# %%
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock

mapper = JordanWignerMapper()


driver = PySCFDriver(atom=f"H 0 0 0; H 0 0 {0.735}", basis="sto-3g")
problem = driver.run()
hamiltonian = problem.hamiltonian.second_q_op()

# we utilize the parity mapper to XLR8 things... and map it to pauli matrices
pauli_hamiltonian = mapper.map(hamiltonian)

#Ansatz Generation
init_state = HartreeFock(problem.num_spatial_orbitals,
                        problem.num_particles,
                        mapper)

ansatz = UCCSD(problem.num_spatial_orbitals,
            problem.num_particles,
            mapper,
            initial_state= init_state)



ansatz.decompose(reps= 1).draw()
# Out:
#      ┌───┐┌───────────────────────────────┐┌───────────────────────────────┐»
# q_0: ┤ X ├┤0                              ├┤0                              ├»
#      └───┘│                               ││                               │»
# q_1: ─────┤1                              ├┤1                              ├»
#      ┌───┐│  exp(-it (IIXY + IIYX))(t[0]) ││  exp(-it (XYII + YXII))(t[1]) │»
# q_2: ┤ X ├┤2                              ├┤2                              ├»
#      └───┘│                               ││                               │»
# q_3: ─────┤3                              ├┤3                              ├»
#           └───────────────────────────────┘└───────────────────────────────┘»
# «     ┌─────────────────────────────────────────────────────────────────────────┐
# «q_0: ┤0                                                                        ├
# «     │                                                                         │
# «q_1: ┤1                                                                        ├
# «     │  exp(-it (YYXY + XYYY + XXXY + YXYY + XYXX + YYYX + YXXX + XXYX))(t[2]) │
# «q_2: ┤2                                                                        ├
# «     │                                                                         │
# «q_3: ┤3                                                                        ├
# «     └─────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# We see that its a quantum circuit! and can transpile/cast it to the state vector!

# %%
import numpy as np
from numpy import sqrt
from qiskit import QuantumCircuit
from qiskit.circuit.library import HGate, IGate, CXGate
from qiskit.quantum_info import Statevector, partial_trace, concurrence
import os


def CalculoInvariantes(state_vector : Statevector) -> list[float]:


    #  Callculo de los inariantes polinomiales
    x = state_vector.data #vector data
    h1 = x[-1] *x[0] - x[1]* x[-2] - x[2] *x[-3] + x[3]* x[-4] -  x[4] *x[-5] + x[5] *x[-6] + x[6] *x[-7] - x[7] *x[-8]
    h2 = np.linalg.det(np.array([
        [x[0],x[4],x[8],x[12]],
        [x[1],x[5],x[9],x[13]],
        [x[2],x[6],x[10],x[14]],
        [x[3],x[7],x[11],x[15]]
    ]))

    h3 = np.linalg.det(np.array([
        [x[0], x[8], x[2], x[10]],
        [x[1], x[9], x[3], x[11]],
        [x[4], x[12], x[6], x[14]],
        [x[5], x[13], x[7], x[15]]
    ] ))
    h4 = np.linalg.det(np.array([
        [x[0] * x[3] - x[1] * x[2], x[3] * x[4] - x[2] * x[5] - x[1] * x[6] + x[0] * x[7], -x[5] * x[6] + x[4] * x[7]],
        [x[3] * x[8] - x[2] * x[9] - x[1] * x[10] + x[0] * x[11], x[7] * x[8] - x[6] * x[9] - x[5] * x[10] + x[4] * x[11] + x[3] * x[12] - x[2] * x[13] - x[1] * x[14] + x[0] * x[15],
            x[7] * x[12] - x[6] * x[13] - x[5] * x[14] + x[4] * x[15]],
        [ -x[9] * x[10] + x[8] * x[11], x[11] * x[12] - x[10] * x[13] - x[9] * x[14] + x[8] * x[15], -x[13] * x[14] + x[12] * x[15]
        ]
    ]))

    #  calcular los invariantes de entrelazamiento
    permutations = [[0], [1], [2], [3], [0, 1], [0, 2], [0, 3], [1, 2], [1, 3], [2, 3], [0, 1, 2], [0, 1, 3], [0, 2, 3], [1, 2, 3]]

    Cab = concurrence(partial_trace(state_vector, [2,3]).data)
    Cac = concurrence(partial_trace(state_vector, [1,3]).data)
    Cad = concurrence(partial_trace(state_vector, [1,2]).data)
    Cbc = concurrence(partial_trace(state_vector, [0,3]).data)
    Cbd = concurrence(partial_trace(state_vector, [0,2]).data)
    Ccd = concurrence(partial_trace(state_vector, [0,1]).data)
    Cgm = min([sqrt(2- 2 * np.trace(partial_trace(state_vector, i).data @ partial_trace(state_vector, i).data)) for i in permutations])

    return [h1.item().real, h2, h3, h4, Cab, Cac, Cad, Cbc, Cbd, Ccd, Cgm]

# %%
from qiskit.primitives import Estimator
from qiskit_algorithms.optimizers import SLSQP, COBYLA
from qiskit_algorithms import VQE

from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.algorithms.initial_points import HFInitialPoint
import multiprocessing as mp

from qiskit.quantum_info import Statevector

def initialize_H2_vqe_chemical(ri= 0.735, mapper= JordanWignerMapper()):
    """
    ri : float_like : inter atomic distance between the two Hydrogen atoms
    mapper : MapperLike: The mapping utilized from a a^daga <---> qubits
    """

    #initialize the hamiltonian
    driver = PySCFDriver(atom=f"H 0 0 0; H 0 0 {ri}", basis="sto-3g")
    problem = driver.run()
    hamiltonian = problem.hamiltonian.second_q_op()

    # we utilize the parity mapper to XLR8 things... and map it to pauli matrices
    pauli_hamiltonian = mapper.map(hamiltonian)

    #Ansatz Generation
    init_state = HartreeFock(problem.num_spatial_orbitals,
                         problem.num_particles,
                         mapper)

    ansatz = UCCSD(problem.num_spatial_orbitals,
               problem.num_particles,
               mapper,
               initial_state= init_state)

    #we will return the ansatz, pauli and the ES problem
    return ansatz, pauli_hamiltonian, problem


def vqe_chemical_ansatz(estimator, ansatz, problem, mapper=JordanWignerMapper(), optimizer= COBYLA()):

    #we generate the VQE algorithm
    vqe = VQE(estimator= estimator,
              ansatz= ansatz,
              optimizer= optimizer)

    #we define again the parity mapper: Maybe we can fix this (?)


    #we initialize the initial point
    initial_point = HFInitialPoint()
    initial_point.ansatz = ansatz
    initial_point.problem = problem
    vqe.initial_point = initial_point.to_numpy_array()


    #We deploy the VQE algorithm
    solver = GroundStateEigensolver(mapper, vqe)


    result = solver.solve(problem)

    gs_energy = result.total_energies[0]
    utilized_ansatz = result.groundstate[0]
    optimized_parameters = result.groundstate[1]

    optimal_ansatz = utilized_ansatz.assign_parameters(optimized_parameters)

    #we return the groundstate energy and the optimal circuit ansatz
    return gs_energy, optimal_ansatz #second one is a circuit



def equilibrium_config(swept_interval, estimator):

    #we try to optimize this for running in parallel but
    # it does not seems to be poosible
    with mp.Pool() as pool:

        num_calc = len( swept_interval )

        energiesH2_list = np.zeros(num_calc)

        class_coefficients = np.zeros((num_calc, 11))

        ground_states = np.zeros((num_calc, 16))


        for i, d in enumerate(swept_interval):

            ansatz_h2, pauli_ham_h2, prob = initialize_H2_vqe_chemical(ri=d)

            gs_energy_d, optimal_ansatz_d = vqe_chemical_ansatz(estimator=estimator,
                                                                ansatz= ansatz_h2,
                                                                problem= prob)

            final_statevector = Statevector(optimal_ansatz_d)

            ground_states[i] = final_statevector.data
            energiesH2_list[i] = gs_energy_d
            class_coefficients[i] = np.array(CalculoInvariantes(final_statevector))



        return energiesH2_list, class_coefficients, final_statevector

# %%
distances = np.arange(0.05, 2.3, 0.05)
estimator = Estimator()

# Llamada a la función y almacenamiento de los resultados
energiesH2, class_coefficients_final, groundstates_UCCSD = equilibrium_config(swept_interval=distances, estimator=estimator)
# Out:
# /tmp/ipykernel_19868/3341291040.py:2: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   estimator = Estimator()
# /tmp/ipykernel_19868/713639071.py:98: ComplexWarning: Casting complex values to real discards the imaginary part
#   ground_states[i] = final_statevector.data
# /tmp/ipykernel_19868/713639071.py:100: ComplexWarning: Casting complex values to real discards the imaginary part
#   class_coefficients[i] = np.array(CalculoInvariantes(final_statevector))

# %%
distances[14]

gs_distance_index = 14

# %%
class_coefficients_final[gs_distance_index]
# Out:
# array([-1.13859783e-01,  4.60500547e-34,  2.87190699e-10,  3.26994706e-11,
#         6.11494143e-05,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.21835979e-04,  2.27719576e-01])
